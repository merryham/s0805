# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font',family='NanumGothic')

# %%
data = pd.read_excel('../data/data.xlsx',encoding='utf-8')
data
# Out:
#               상권_코드_명 서비스_업종_코드_명        lat         lng  창업위험지수  \
# 0               시청역_2         PC방  37.565704  126.976862       3
# 1              북아현로4길         PC방  37.559711  126.958390       3
# 2               충정로6길         PC방  37.560125  126.963295       3
# 3              왕산로43길         PC방  37.584591  127.047720       3
# 4               흑석로9길         PC방  37.508327  126.958066       4
# 5             양재대로96길         PC방  37.529413  127.138777       2
# 6             디지털로37길         PC방  37.490052  126.898328       2
# 7              봉천로13길         PC방  37.490233  126.930790       2
# 8             디지털로57길         PC방  37.491737  126.901149       2
# 9               종로65길         PC방  37.575677  127.019961       2
# 10                당곡길         PC방  37.490577  126.928564       2
# 11            디지털로37길         PC방  37.490052  126.898328       2
# 12        상도4동도깨비골목시장         PC방  37.498762  126.952647       4
# ...

# %%
data.columns
# Out:
# Index(['상권_코드_명', '서비스_업종_코드_명', 'lat', 'lng', '창업위험지수', '평균시가', '상권변화',
#        '유동인구', '지하철', '인구밀도', '영업평균', '평균매출건수', '평균매출'],
#       dtype='object')

# %%
new = pd.pivot_table(data,index=['서비스_업종_코드_명'],values=['창업위험지수', '평균시가', '상권변화',
       '유동인구', '지하철', '인구밀도', '영업평균', '평균매출', '평균매출건수'],aggfunc=[np.mean])

# %%
new
# Out:
#                  mean                                                    \
#                  상권변화        영업평균          유동인구          인구밀도       지하철
# 서비스_업종_코드_명
# PC방          3.610725  108.897219  1.683106e+06  27070.545184  2.120655
# 가구·가전        3.592572  109.304446  1.683070e+06  26654.074845  2.334271
# 가전제품수리       3.502288  109.378719  1.564333e+06  26689.153318  2.184211
# 건강보조식품       3.615341  109.331998  1.675953e+06  26946.639954  2.224957
# 네일숍          3.658889  108.503033  1.757411e+06  26855.246850  2.258516
# 노래방          3.597553  109.024147  1.625451e+06  26267.005151  2.151642
# 당구장          3.612372  108.771696  1.679362e+06  25862.130841  2.308856
# 두발미용업        3.608954  108.916408  1.602165e+06  25779.116201  2.199793
# 부동산중개업       3.738544  108.571429  1.781221e+06  25354.563342  2.676550
# 분식전문점        3.603197  108.821088  1.619553e+06  25476.968031  2.243410
# 서적·문구        3.583725  108.743349  1.618307e+06  25338.419014  2.294210
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(new.corr(), linewidths=0.1, vmax=0.5, cmap=plt.cm.gist_heat, linecolor='white', annot=True)
plt.show()
